# %%
#importing packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We have two datasets of Wine, one containing White-Wine data and other containing Red-Wine data \
# Our target variable is quality and rest is our predictors

# %%
#Reading Data
redWine = pd.read_csv(r"C:\Users\Aaditya Ghag\Downloads\wineData\Wine-quality-classification\data\winequality-red.csv", delimiter=';')
whiteWine = pd.read_csv(r"C:\Users\Aaditya Ghag\Downloads\wineData\Wine-quality-classification\data\winequality-white.csv", delimiter=',')

# %%
#Adding an additional feature *Type*
redWine['Type'] = 'Red'
whiteWine['Type'] = 'White'

# %%
redWine.shape, whiteWine.shape
# Out:
# ((1599, 13), (4898, 13))

# %% [markdown]
# We will combine both the datasets into a single dataset

# %%
data = pd.concat([whiteWine, redWine],axis=0,join='outer')

# %%
data.shape
# Out:
# (6497, 13)

# %% [markdown]
# Let’s explore some data points present in the data.

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality   Type
# 0      8.8        6  White
# 1      9.5        6  White
# 2     10.1        6  White
# 3      9.9        6  White
# 4      9.9        6  White

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality Type
# 1594     10.5        5  Red
# 1595     11.2        6  Red
# 1596     11.0        6  Red
# 1597     10.2        5  Red
# 1598     11.0        6  Red

# %% [markdown]
# Now the dataset contains the white wine entries first and then the red wine, so i will shuffle the data

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.15         0.42             1.7      0.045
# 1            6.3              0.22         0.27             4.5      0.036
# 2           11.7              0.28         0.47             1.7      0.054
# 3            6.2              0.26         0.32            15.3      0.031
# 4            6.8              0.25         0.18             1.4      0.056
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 49.0                 154.0  0.99200  3.00       0.60
# 1                 81.0                 157.0  0.99280  3.05       0.76
# 2                 17.0                  32.0  0.99686  3.15       0.67
# 3                 64.0                 185.0  0.99835  3.31       0.61
# 4                 13.0                 137.0  0.99350  3.11       0.42
#
#    alcohol  quality   Type
# 0     10.4        6  White
# 1     10.7        7  White
# 2     10.6        7    Red
# 3      9.4        5  White
# 4      9.5        5  White

# %% [markdown]
# Let's summarizes the statistics of each feature using the describe() function

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %% [markdown]
# There is a very huge difference between 75th% tile and maximum values of features <b> Residual Sugar, free sulfur dioxide, total sulfur dioxide. </b>So there are outliers present in the dataset

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Type                     object
# dtype: object

# %% [markdown]
# The dataset has only one categorical feature <b>Type</b>

# %%
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# There are no missing values in the dataset

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.set_style("darkgrid")
sns.countplot(data.quality)

# %% [markdown]
# <b>Quality</b> feature contains very less values for the categories <b>3,4,8,9</b>

# %%
sns.countplot(data.Type)

# %% [markdown]
# The dataset contains more White-wine observations than the Red-wine

# %% [markdown]
# # Boxplot for checking outliers
# Here i have plotted for all the features except <b>Quality and Type</b>

# %%
plt.figure(figsize=(15,25))
for i, column in enumerate(list(data.columns[:-2])):
    plt.subplot(6, 2, i+1)
    sns.boxplot(data[column])
    plt.grid()

# %% [markdown]
# ### Inference drawn from the above plots
# Except <b>alcohol</b> and <b>density</b> almost all the features contain many outliers

# %% [markdown]
# # Distribution plots

# %%
plt.figure(figsize=(15,25))
for i, column in enumerate(list(data.columns[:-2])):
    plt.subplot(6, 2, i+1)
    sns.distplot(data[column])
    plt.grid()

# %% [markdown]
# ### Inference drawn from the above plots
# The <b>pH</b> feature follows a normal distriution while rest features have almost positively skewed distribution

# %% [markdown]
# # Line plots

# %%
plt.figure(figsize=(15,25))
for i, column in enumerate(list(data.columns[:-2])):
    plt.subplot(6, 2, i+1)
    sns.lineplot(x='quality',y=column,hue='Type',data=data)
    plt.grid()

# %% [markdown]
# ### Inference drawn from the above plots
# <br>
# <li>
# The alcohol and sulphates content increases as the quality increases
# </li>
# <li>
# The chlorides and volatile acidity content decreses as the quality increases
# </li>

# %% [markdown]
# # Collinearity check
#
# I have used pandas <b>.corr()</b> function and to visualize the correlation matrix using a heatmap in seaborn.

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# ### Inference drawn from the above heatmap
# <br>
# <li>total sulfur dioxide and free sulfur dioxide have highest correlation of 0.72, so one of them can be dropped while building model.</li>
# <li>density and residual sugar have correlation of 0.55, so one of them can be ignored.</li>
#
# <li>alcohol and density has negative high correlation of -0.69, so i will take one.</li>

# %% [markdown]
# Now to choose which one to drop amongst the two highly correlated features while building the model, i have checked individual collinearity with the response variable <b>Quality</b>. So the feature having max value will be choosed.

# %%
#Choosing between alcohol and density
#Printing correlation
print(round(data[["alcohol","quality",]].corr(),2),end="\n\n")
print(round(data[["density","quality",]].corr(),2))
# Out:
#          alcohol  quality
# alcohol     1.00     0.44
# quality     0.44     1.00
#
#          density  quality
# density     1.00    -0.31
# quality    -0.31     1.00

# %% [markdown]
# Density feature should be dropped as it has low correlation value

# %%
#As per above correlation, checking the scatter plots
sns.lmplot(x='alcohol',y='density',hue='Type',data=data,fit_reg=False)

# %%
#Choosing between total sulfur dioxide and free sulfur dioxide
#Printing correlation
print(round(data[["total sulfur dioxide","quality",]].corr(),2),end="\n\n")
print(round(data[["free sulfur dioxide","quality",]].corr(),2))
# Out:
#                       total sulfur dioxide  quality
# total sulfur dioxide                  1.00    -0.04
# quality                              -0.04     1.00
#
#                      free sulfur dioxide  quality
# free sulfur dioxide                 1.00     0.06
# quality                             0.06     1.00

# %% [markdown]
# Here i will choose the free sulfur dioxide feature

# %%
#As per above correlation, checking the scatter plots
sns.lmplot(x='total sulfur dioxide',y='free sulfur dioxide',hue='Type',data=data,fit_reg=False)

# %% [markdown]
# # Making Pipeline

# %%
#importing sklearn packages
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,LabelEncoder,MinMaxScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn_features.transformers import DataFrameSelector
from sklearn.metrics import roc_auc_score,accuracy_score
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
import warnings
warnings.filterwarnings("ignore")

# %%
# type_dict = {'Red':0,'White':1}
# data["Type"] = data["Type"].map(type_dict)

# %%
X = data.drop(columns=["quality","free sulfur dioxide","density"],axis=1)
y = data["quality"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2,stratify=y)
(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# ((5197, 10), (1300, 10), (5197,), (1300,))

# %%
X_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2087            7.6              0.42         0.25             3.9      0.104
# 6049            6.5              0.29         0.25            10.6      0.039
# 2570            8.2              0.34         0.29             5.2      0.076
# 5906            5.9              0.30         0.30             2.0      0.030
# 5787            6.8              0.22         0.32             5.9      0.054
#
#       total sulfur dioxide    pH  sulphates  alcohol   Type
# 2087                  90.0  3.15       0.57      9.1    Red
# 6049                 120.0  3.31       0.34     10.1  White
# 2570                  92.0  2.95       0.39     12.5  White
# 5906                 142.0  3.41       0.41     12.9  White
# 5787                 152.0  3.20       0.57     10.8  White

# %% [markdown]
# Looking at the data, it needs to be scaled and the <b>Type</b> column needs to be labelled.
# I have used <b>ColumnTransformer</b> function to do both the tasks
#
# ## ColumnTransformer
# Applies transformers to columns of an array or pandas DataFrame.
# This estimator allows different columns or column subsets of the input to be transformed separately and the features generated by each transformer will be concatenated to form a single feature space. This is useful for heterogeneous or columnar data, to combine several feature extraction mechanisms or transformations into a single transformer.

# %%
#Getting numerical features
numeric_features = list(X_train.columns[:-1])
#Getting categorical features
cat_features = list(X_train.columns[-1:])
print("Numerical Features : {}".format(numeric_features),end="\n\n")
print("Categorical Features : {}".format(cat_features))
# Out:
# Numerical Features : ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'total sulfur dioxide', 'pH', 'sulphates', 'alcohol']
#
# Categorical Features : ['Type']

# %% [markdown]
# I have used a <b>CustomLabelEncoder</b> class for label encoding, because the standard Label Encoder does not work with pipeline.

# %%
class CustomLabelEncoder(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return LabelEncoder().fit_transform(X).reshape(-1,1);

# %%
#Defining ColumnTransformer
columnTransformer = ColumnTransformer([('scaler', StandardScaler(), numeric_features),
                                       ('encode', CustomLabelEncoder(), cat_features)], 
                                      remainder='passthrough')

# %%
#Checking results
pd.DataFrame(columnTransformer.fit_transform(X_train),columns=X_train.columns).head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.308333          0.226667     0.150602        0.106452   0.157807
# 1       0.216667          0.140000     0.150602        0.322581   0.049834
# 2       0.358333          0.173333     0.174699        0.148387   0.111296
# 3       0.166667          0.146667     0.180723        0.045161   0.034884
# 4       0.241667          0.093333     0.192771        0.170968   0.074751
#
#    total sulfur dioxide        pH  sulphates   alcohol  Type
# 0              0.233010  0.333333   0.196629  0.159420   0.0
# 1              0.316227  0.457364   0.067416  0.304348   1.0
# 2              0.238558  0.178295   0.095506  0.652174   1.0
# 3              0.377254  0.534884   0.106742  0.710145   1.0
# 4              0.404993  0.372093   0.196629  0.405797   1.0

# %%
#Applying different classifier algorithmns
classifiers = [
    LogisticRegression(multi_class='multinomial',solver='newton-cg'),
    KNeighborsClassifier(),
    SVC(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    ]

#Iterator 
for i,classifier in enumerate(classifiers):
    
    print("Initializing Pipeline",end="\n\n")
    #Defining Pipeline
    pipe = Pipeline(steps=[('preprocessor', columnTransformer),('classifier', classifier)],verbose=True)
    pipe.fit(X_train, y_train)
    print("\n")
    #Printing current classifier
    print("{}.{}".format(i+1, classifier),end="\n\n")
    #Printing score
    print("model score: %.3f" % pipe.score(X_test, y_test),end="\n")
    if(i==4):
        break
    print("-----------------------------------------------------------------------",end="\n\n")
# Out:
# Initializing Pipeline
#
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=   0.5s
#
#
# 1.LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)
#
# model score: 0.538
# -----------------------------------------------------------------------
#
# Initializing Pipeline
#
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=   0.0s
#
#
# 2.KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
# model score: 0.552
# -----------------------------------------------------------------------
#
# Initializing Pipeline
#
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=   2.2s
#
#
# 3.SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
#
# model score: 0.530
# -----------------------------------------------------------------------
#
# Initializing Pipeline
#
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=   0.1s
#
#
# 4.DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
# model score: 0.591
# -----------------------------------------------------------------------
#
# Initializing Pipeline
#
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=   0.2s
#
#
# 5.RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
# model score: 0.652

# %% [markdown]
# # Tuning RandomForestClassifier

# %%
#Generating Random Parameters

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 800, num = 5)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 50, num = 5)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'RandomForestClassifier__n_estimators': n_estimators,
               'RandomForestClassifier__max_features': max_features,
               'RandomForestClassifier__max_depth': max_depth,
               'RandomForestClassifier__min_samples_split': min_samples_split,
               'RandomForestClassifier__min_samples_leaf': min_samples_leaf,
               'RandomForestClassifier__bootstrap': bootstrap}
random_grid
# Out:
# {'RandomForestClassifier__n_estimators': [200, 350, 500, 650, 800],
#  'RandomForestClassifier__max_features': ['auto', 'sqrt'],
#  'RandomForestClassifier__max_depth': [10, 20, 30, 40, 50, None],
#  'RandomForestClassifier__min_samples_split': [2, 5, 10],
#  'RandomForestClassifier__min_samples_leaf': [1, 2, 4],
#  'RandomForestClassifier__bootstrap': [True, False]}

# %%
pipe = Pipeline(steps=[('preprocessor', columnTransformer),('RandomForestClassifier', RandomForestClassifier())])
grid = RandomizedSearchCV(estimator=pipe,param_distributions=random_grid,cv=5,verbose=2,n_iter = 10,random_state=28,n_jobs=-1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  2.8min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=Pipeline(memory=None,
#                                       steps=[('preprocessor',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='passthrough',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('scaler',
#                                                                                MinMaxScaler(copy=True,
#                                                                                             feature_range=(0,
#                                                                                                            1)),
#                                                                                ['fixed '
#                                                                                 'acidity',
#                                                                                 'volatile '
#                                                                                 'acidity',
#                                                                                 'citric '
#                                                                                 'acid',
#                                                                                 'residual '
#                                                                                 'sugar',
#                                                                                 '...
#                                         'RandomForestClassifier__max_depth': [10,
#                                                                               20,
#                                                                               30,
#                                                                               40,
#                                                                               50,
#                                                                               None],
#                                         'RandomForestClassifier__max_features': ['auto',
#                                                                                  'sqrt'],
#                                         'RandomForestClassifier__min_samples_leaf': [1,
#                                                                                      2,
#                                                                                      4],
#                                         'RandomForestClassifier__min_samples_split': [2,
#                                                                                       5,
#                                                                                       10],
#                                         'RandomForestClassifier__n_estimators': [200,
#                                                                                  350,
#                                                                                  500,
#                                                                                  650,
#                                                                                  800]},
#                    pre_dispatch='2*n_jobs', random_state=28, refit=True,
#                    return_train_score=False, scoring=None, verbose=2)

# %%
grid.best_params_
# Out:
# {'RandomForestClassifier__n_estimators': 650,
#  'RandomForestClassifier__min_samples_split': 2,
#  'RandomForestClassifier__min_samples_leaf': 1,
#  'RandomForestClassifier__max_features': 'sqrt',
#  'RandomForestClassifier__max_depth': None,
#  'RandomForestClassifier__bootstrap': True}

# %%
rf = RandomForestClassifier(n_estimators=650,min_samples_split=2,min_samples_leaf=1,max_features='sqrt',max_depth=None,
                      bootstrap=True)
pipe = Pipeline(steps=[('preprocessor', columnTransformer),('classifier', rf)],verbose=True)
pipe.fit(X_train, y_train)
pipe.score(X_test,y_test)
# Out:
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=  12.6s
# 0.6738461538461539
